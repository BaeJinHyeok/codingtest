# %%
detective =(( "Sherlok", "Holmes"),( " 221 Baker Street", "Marylebone", "London"))
(firstname, lastname),(street, addr, city) = detective

# %%
detective
# Out:
# (('Sherlok', 'Holmes'), (' 221 Baker Street', 'Marylebone', 'London'))

# %%
firstname
# Out:
# 'Sherlok'

# %%
street
# Out:
# ' 221 Baker Street'

# %%
print("first name= {} , last name = {}".format(firstname,lastname))
# Out:
# first name= Sherlok , last name = Sherlok

# %%
print(" street={}, addr={}".format(street, addr))
# Out:
#  street= 221 Baker Street, addr=Marylebone
