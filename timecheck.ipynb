# %%
import datetime
# Recognize 함수에서 실행하기 
now = datetime.datetime.now()
#period = self.period.currentText()         3받으면 /if 3 번 실행 Start , End 값 나오고 /Start, End 값으로 비교연산 후 /출석관련메시지
#for 1 range 8  period = i ++ strat = +110 end = +150 if period == i: Start = 900 End = 950
#if period == 1:               
 #   Strat = 900 
 #   End = 950
#if period == 2:
#    Strat = 1010 
#    End = 1100
#if period == 3:
#    Strat = 1110 
#    End = 1200
#if period == 4:
    #Strat = 900 
    #End = 950
#if period == 5:
    #Strat = 900 
    #End = 950
#if period == 6:
    #Strat = 900 
    #End = 950
#if period == 7:
    #Strat = 900 
    #End = 950

    
#ComboboxToday = self.today.currentText()
today = (str(datetime.date.today().isoformat()))
recognizetoday = (str(datetime.date.today().isoformat()))
print(now)
print(str(now.hour))
print(str(now.minute))
print(str(now.second))
print(str(now.hour)+str(now.minute))
a = str(2220) # Start 
b = str(2300) # End
#c = (str(now.hour)+str(now.minute))
c = now.strftime('%H%M')
d = "출석"
e = "지각"
f = "결석"
g = "오늘 날짜가 아닙니다" # 메시지 띄워주고 얼굴 인식 창 닫기
if a >= c: #and ComboboxToday = today:
    print(d)
elif a < c and b>=c: #and ComboboxToday = today:
    print(e)
elif b < c:
    print(f) #and ComboboxToday = today:
else:
    print(g)
time = now.strftime("%H%M")
print("time:", time)
# Out:
# 2020-07-03 22:11:04.379822
# 22
# 11
# 4
# 2211
# 출석
# time: 2211
