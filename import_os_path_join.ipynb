# %%
import os

# %%
base_dir = '/content/drive/My Drive/제목없는 폴더/images'
train_dir = os.path.join(base_dir, 'Train')
validation_dir = os.path.join(base_dir, 'Validation')

# %%
import tensorflow as tf

# %%
import os

osList = ['C:\\', 'User', 'jh']
resultPath = os.path.join(*osList) # Join 함수로 인자를 넘길 땐 리스크를 전개하여 넘겨야함 -> *(애프터리스크)를 사용하여 전개함
resultPath

#mybirthday, import os study
# Out:
# 'C:\\/User/jh'
