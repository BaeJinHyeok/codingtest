# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://movie.naver.com/movie/sdb/rank/rmovie/nhn?sel=cur&date=20191002')
soup = BeautifulSoup(res.content, 'html.parser')
print("hello")


titles = soup.select('#old_content > table > tbody > tr > td.title')
for tittle in titles:
    print(title.get_text())
# Out:
# hello
